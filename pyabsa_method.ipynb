# %%
! pip install pyabsa

# %%
from pyabsa import AspectTermExtraction as ATEPC, available_checkpoints

# Check available checkpoints
checkpoint_map = available_checkpoints()

# # Initialize the aspect extractor with a multilingual checkpoint
aspect_extractor = ATEPC.AspectExtractor('english',
                                         auto_device=True,  # Load model on GPU if available
                                         cal_perplexity=True,
                                         )

# %%
df = pd.read_csv("Translated_Data.csv")
data = df.set_axis(['review_fa', 'aspects_fa', 'sentiments', 'review_en', 'aspects'], axis=1)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
import pandas as pd
# # Process the entire dataset
reviews = data['review_en'].tolist()
# reviews = ["It was a great laptop and had a nice keyboard, although they could've done better with the screen. but overall its a good product for daily tasks. "]
results = aspect_extractor.batch_predict(reviews,
                                         save_result=True,
                                         print_result=True,  # Print the result
                                         pred_sentiment=True,  # Predict the sentiment of extracted aspect terms
                                         ignore_error=True  # Ignore errors during prediction
                                         )

# # Convert results to a DataFrame
results_df = pd.DataFrame(results)

# Save results to CSV
results_df.to_csv('aspect_sentiment_results.csv', index=False)

# # Alternatively, save results to JSON
results_df.to_json('aspect_sentiment_results.json', orient='records', lines=True)

# # Display the first few rows of the results
results_df.head()
# Out:
# <frozen importlib._bootstrap>:914: ImportWarning: _PyDrive2ImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _GenerativeAIImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _OpenCVImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: APICoreClientInfoImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _AltairImportHook.find_spec() not found; falling back to find_module()
# ...
